# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import  KMeans

# %%
data=pd.read_csv('D:/DATA SCIENCE/DS ML Files/Iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.describe().T
# Out:
#                count       mean        std  min    25%    50%     75%    max
# Id             150.0  75.500000  43.445368  1.0  38.25  75.50  112.75  150.0
# SepalLengthCm  150.0   5.843333   0.828066  4.3   5.10   5.80    6.40    7.9
# SepalWidthCm   150.0   3.054000   0.433594  2.0   2.80   3.00    3.30    4.4
# PetalLengthCm  150.0   3.758667   1.764420  1.0   1.60   4.35    5.10    6.9
# PetalWidthCm   150.0   1.198667   0.763161  0.1   0.30   1.30    1.80    2.5

# %%
data.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
sns.boxplot(y=data['SepalLengthCm'])
# Out:
# <AxesSubplot:ylabel='SepalLengthCm'>

# %%
sns.boxplot(y=data['SepalWidthCm'])
# Out:
# <AxesSubplot:ylabel='SepalWidthCm'>

# %%
sns.boxplot(y=data['PetalLengthCm'])
# Out:
# <AxesSubplot:ylabel='PetalLengthCm'>

# %%
sns.boxplot(y=data['PetalWidthCm'])
# Out:
# <AxesSubplot:ylabel='PetalWidthCm'>

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data_new=data.drop(['Id','Species'],axis=1)
data_new
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
X=StandardScaler().fit_transform(data_new)
X
# Out:
# array([[-9.00681170e-01,  1.03205722e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00, -1.24957601e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.38535265e+00,  3.37848329e-01, -1.39813811e+00,
#         -1.31297673e+00],
#        [-1.50652052e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.02184904e+00,  1.26346019e+00, -1.34127240e+00,
#         -1.31297673e+00],
#        [-5.37177559e-01,  1.95766909e+00, -1.17067529e+00,
#         -1.05003079e+00],
#        [-1.50652052e+00,  8.00654259e-01, -1.34127240e+00,
#         -1.18150376e+00],
#        [-1.02184904e+00,  8.00654259e-01, -1.28440670e+00,
#         -1.31297673e+00],
#        [-1.74885626e+00, -3.56360566e-01, -1.34127240e+00,
#         -1.31297673e+00],
#        [-1.14301691e+00,  1.06445364e-01, -1.28440670e+00,
#         -1.44444970e+00],
#        [-5.37177559e-01,  1.49486315e+00, -1.28440670e+00,
#         -1.31297673e+00],
# ...

# %%
kmeans=KMeans()

# %%
model=kmeans.fit(X)

# %%
centers=model.cluster_centers_
centers
# Out:
# array([[ 2.39194352e-01, -1.42098562e-01,  3.98396910e-01,
#          3.28000713e-01],
#        [-1.38535265e+00, -3.49675592e-02, -1.33811320e+00,
#         -1.33488889e+00],
#        [ 9.88436083e-01,  2.74738430e-01,  9.61788607e-01,
#          1.22086597e+00],
#        [-5.74459981e-01,  1.97546931e+00, -1.27128385e+00,
#         -1.20173037e+00],
#        [ 4.25788148e-01, -8.06987393e-01,  7.92687961e-01,
#          8.04430053e-01],
#        [-3.64080601e-01, -1.41420269e+00,  1.07449102e-01,
#          1.75297293e-03],
#        [ 2.00734772e+00,  6.43720976e-02,  1.45548631e+00,
#          1.06548882e+00],
#        [-9.64453734e-01,  8.98087087e-01, -1.29637843e+00,
#         -1.21610191e+00]])
